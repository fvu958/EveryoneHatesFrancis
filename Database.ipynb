# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import requests 
from pprint import pprint
import json
from config import apikey

# %%
csvpath = os.path.join("actors.csv")
csvpath1 = os.path.join("movie_data_final.csv")
movie = pd.read_csv(csvpath1, engine = 'python')
actors = pd.read_csv(csvpath, engine = 'python')
actors.dropna(axis=1, how="any")
movie.dropna(axis=1, how="any")
# Out:
#        adult           budget  \
# 0      FALSE  $30,000,000.00
# 1      FALSE         65000000
# 2      FALSE                0
# 3      FALSE         16000000
# 4      FALSE                0
# 5      FALSE         60000000
# 6      FALSE         58000000
# 7      FALSE                0
# 8      FALSE         35000000
# 9      FALSE         58000000
# 10     FALSE         62000000
# 11     FALSE                0
# 12     FALSE                0
# 13     FALSE         44000000
# 14     FALSE         98000000
# 15     FALSE         52000000
# 16     FALSE         16500000
# 17     FALSE          4000000
# 18     FALSE         30000000
# 19     FALSE         60000000
# 20     FALSE         30250000
# 21     FALSE                0
# 22     FALSE         50000000
# 23     FALSE                0
# 24     FALSE          3600000
# 25     FALSE                0
# 26     FALSE         12000000
# 27     FALSE                0
# 28     FALSE         18000000
# 29     FALSE                0
# ...      ...              ...
# 45436  FALSE                0
# 45437  FALSE                0
# 45438  FALSE                0
# 45439  FALSE                0
# 45440  FALSE                0
# 45441  FALSE                0
# 45442  FALSE                0
# 45443  FALSE                0
# 45444  FALSE                0
# 45445  FALSE                0
# 45446  FALSE                0
# 45447  FALSE                0
# 45448  FALSE                0
# 45449  FALSE                0
# 45450  FALSE                0
# 45451  FALSE                0
# 45452  FALSE                0
# 45453  FALSE                0
# 45454  FALSE                0
# 45455  FALSE                0
# 45456  FALSE                0
# 45457  FALSE                0
# 45458  FALSE                0
# 45459  FALSE                0
# 45460  FALSE                0
# 45461  FALSE                0
# 45462  FALSE                0
# 45463  FALSE                0
# 45464  FALSE                0
# 45465  FALSE                0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# 5      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...     949
# 6      [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...   11860
# 7      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   45325
# 8      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...    9091
# 9      [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...     710
# 10     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    9087
# 11     [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...   12110
# 12     [{'id': 10751, 'name': 'Family'}, {'id': 16, '...   21032
# 13     [{'id': 36, 'name': 'History'}, {'id': 18, 'na...   10858
# 14     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...    1408
# 15     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...     524
# 16     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...    4584
# 17     [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...       5
# 18     [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...    9273
# 19     [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...   11517
# 20     [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'nam...    8012
# 21     [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...    1710
# 22     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...    9691
# 23     [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...   12665
# 24     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...     451
# 25                         [{'id': 18, 'name': 'Drama'}]   16420
# 26     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    9263
# 27     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   17015
# 28     [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...     902
# 29     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...   37557
# ...                                                  ...     ...
# 45436  [{'id': 28, 'name': 'Action'}, {'id': 9648, 'n...   45527
# 45437  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...  455661
# 45438                      [{'id': 18, 'name': 'Drama'}]  327237
# 45439  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...   84710
# 45440  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...   39562
# 45441                     [{'id': 35, 'name': 'Comedy'}]   14008
# 45442                                                 []   44330
# 45443  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...   49279
# 45444                    [{'id': 14, 'name': 'Fantasy'}]   44333
# 45445  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...   49277
# 45446  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...   49271
# 45447                                                 []   44324
# 45448                                                 []  122036
# 45449  [{'id': 16, 'name': 'Animation'}, {'id': 10751...   14885
# 45450  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...   49280
# 45451  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...  106807
# 45452                [{'id': 99, 'name': 'Documentary'}]  276895
# 45453  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...  404604
# 45454  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  420346
# 45455                                                 []   67179
# 45456  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...   84419
# 45457  [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...  390959
# 45458                     [{'id': 27, 'name': 'Horror'}]  289923
# 45459           [{'id': 878, 'name': 'Science Fiction'}]  222848
# 45460  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45462                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464                                                 []  227506
# 45465                                                 []  461257
#
#                           original_title
# 0                              Toy Story
# 1                                Jumanji
# 2                       Grumpier Old Men
# 3                      Waiting to Exhale
# 4            Father of the Bride Part II
# 5                                   Heat
# 6                                Sabrina
# 7                           Tom and Huck
# 8                           Sudden Death
# 9                              GoldenEye
# 10                The American President
# 11           Dracula: Dead and Loving It
# 12                                 Balto
# 13                                 Nixon
# 14                      Cutthroat Island
# 15                                Casino
# 16                 Sense and Sensibility
# 17                            Four Rooms
# 18        Ace Ventura: When Nature Calls
# 19                           Money Train
# 20                            Get Shorty
# 21                               Copycat
# 22                             Assassins
# 23                                Powder
# 24                     Leaving Las Vegas
# 25                               Othello
# 26                          Now and Then
# 27                            Persuasion
# 28           La CitÃ© des Enfants Perdus
# 29           æ‘‡å•Šæ‘‡ï¼Œæ‘‡åˆ°å¤–å©†æ¡¥
# ...                                  ...
# 45436                    The Final Storm
# 45437                     In a Heartbeat
# 45438             Bloed, Zweet en Tranen
# 45439                       Jungle Woman
# 45440                  To Be Fat Like Me
# 45441                        Cadet Kelly
# 45442               Le tripot clandestin
# 45443  L'Homme Ã  la tÃªte de caoutchouc
# 45444                Les cartes vivantes
# 45445           Les affiches en goguette
# 45446            Le locataire diabolique
# 45447               Le Roi du maquillage
# 45448  Les Transmutations imperceptibles
# 45449   Pooh's Heffalump Halloween Movie
# 45450                  L'Homme orchestre
# 45451     Nouvelles luttes extravagantes
# 45452                        Deep Hearts
# 45453                                Maa
# 45454                  The Morning After
# 45455         San Michele aveva un gallo
# 45456                   House of Horrors
# 45457          Shadow of the Blair Witch
# 45458                The Burkittsville 7
# 45459                    Caged Heat 3000
# 45460                         Robin Hood
# 45461                      Ø±Ú¯ Ø®ÙˆØ§Ø¨
# 45462                Siglo ng Pagluluwal
# 45463                           Betrayal
# 45464                Satana likuyushchiy
# 45465                           Queerama
#
# [45466 rows x 5 columns]

# %%
database = actors.merge(movie, on = 'id', how = 'inner')

# %%
df2 = database['production_companies']
print(df2[0])
import ast
prod = []
def get_production(prodstr):
    prodlist = ast.literal_eval(prodstr)
    if not prodlist:
        return ''
    return prodlist[0]['name']

for object in df2:
    try:
        number = get_production(object)
        prod.append(number)
    except Exception as e:
            print(e)
prod_dict = {
    "prod": prod
}

prod_df = pd.DataFrame(prod_dict)
prod_df.head()
# Out:
# [{'name': 'Villealfa Filmproduction Oy', 'id': 2303}, {'name': 'Finnish Film Foundation', 'id': 2396}]
# malformed node or string: nan
# malformed node or string: nan
# malformed node or string: nan
#                           prod
# 0  Villealfa Filmproduction Oy
# 1  Villealfa Filmproduction Oy
# 2                Miramax Films
# 3           Universal Pictures
# 4                    Lucasfilm

# %%
df3 = database['cast']

lead = []

for object in df3:
    try:
        number1 = get_production(object)
        lead.append(number1)
    except Exception as e:
            print(e)
cast_dict = {
    "lead": lead
}
cast_df = pd.DataFrame(cast_dict)
cast_df.head()
# Out:
#                 lead
# 0        Turo Pajala
# 1  Matti PellonpÃ¤Ã¤
# 2           Tim Roth
# 3     Emilio Estevez
# 4        Mark Hamill

# %%
df4 = database['spoken_languages']
lang = []

for object in df3:
    try:
        number2 = get_production(object)
        lang.append(number2)
    except Exception as e:
            print(e)
lang_dict = {
    "lang": lang
}
lang_df = pd.DataFrame(lang_dict)
lang_df.head()
# Out:
#                 lang
# 0        Turo Pajala
# 1  Matti PellonpÃ¤Ã¤
# 2           Tim Roth
# 3     Emilio Estevez
# 4        Mark Hamill

# %%
cleaned = database[['id','release_date','revenue','runtime','budget', 'popularity', 
                    'imdb_id','status','tagline','title',
                    'video','vote_average','vote_count']]
cleaned['production_comp'] = prod_df['prod']
cleaned['production_comp'] = cast_df['lead']
cleaned['production_comp'] = lang_df['lang']

cleaned.head()
# Out:
# C:\Users\GNIEHAUS\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\GNIEHAUS\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\GNIEHAUS\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    id release_date      revenue  runtime    budget popularity    imdb_id  \
# 0   2   10/21/1988          0.0     69.0         0   3.860491  tt0094675
# 1   3   10/16/1986          0.0     76.0         0    2.29211  tt0092149
# 2   5    12/9/1995    4300000.0     98.0   4000000   9.026586  tt0113101
# 3   6   10/15/1993   12136938.0    110.0         0   5.538671  tt0107286
# 4  11    5/25/1977  775398007.0    121.0  11000000  42.149697  tt0076759
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released                                                NaN
# 2  Released  Twelve outrageous guests. Four scandalous requ...
# 3  Released     Don't move. Don't whisper. Don't even breathe.
# 4  Released       A long time ago in a galaxy far, far away...
#
#                  title  video  vote_average  vote_count    production_comp
# 0                Ariel  False           7.1        44.0        Turo Pajala
# 1  Shadows in Paradise  False           7.1        35.0  Matti PellonpÃ¤Ã¤
# 2           Four Rooms  False           6.5       539.0           Tim Roth
# 3       Judgment Night  False           6.4        79.0     Emilio Estevez
# 4            Star Wars  False           8.1      6778.0        Mark Hamill

# %%
# years = ["2005""2006", "2007", "2008", "2009"]
# url = "http://www.omdbapi.com"
# actors = []

# for number in imdb:

#     for id in years:
#         try:
#             params = {
#                 "apikey":apikey, 
#                 "y":id,
#                 "i": number
#                             }
        
#             response = requests.get(url, params = params).json()
#             print(response)
#         except Exception as e:
#             print(e)

# print(json.dumps(response, indent=4, sort_keys=True))
